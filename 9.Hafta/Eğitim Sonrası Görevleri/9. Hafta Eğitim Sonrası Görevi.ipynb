# %% [markdown]
# # Problem 1
#
# Kumanda isminde bir sınıf oluşturarak aşağıdaki işlemleri yapmasını sağlayan fonksiyonları sınıf içerisinde yazalım.
# 1. Tv Aç
# 2. Tv Kapat
# 3. Ses Ayarları
# 4. Kanal Ekle
# 5. Kanal Sayısını Öğrenme
# 6. Rastgele Kanala Geçme
# 7. Televizyon Bilgileri
#
#
# Kumandayı kapatmak için q tuşuna basılmalı ve diğer durumlarda hangi işlemi yapmak istediği sorulmalıdır. Her işlemde gerekli fonksiyonunun sınıf içerisinden çağırılması gerekmektedir.
#
# random ve time kütüphanesini araştırarak kullanabilirsiniz.
#
# Kendi istediğiniz özellikleri eklemekte serbetsiniz.

# %%
import random
import time

class Kumanda:
    def __init__(self, tv_durum="Kapalı", ses=10, kanal_listesi=["TRT"], mevcut_kanal="TRT"):
        self.tv_durum = tv_durum
        self.ses = ses
        self.kanal_listesi = kanal_listesi
        self.mevcut_kanal = mevcut_kanal

    def tv_ac(self):
        if self.tv_durum == "Açık":
            print("Televizyon zaten açık!")
        else:
            self.tv_durum = "Açık"
            print("Televizyon açıldı.")

    def tv_kapat(self):
        if self.tv_durum == "Kapalı":
            print("Televizyon zaten kapalı!")
        else:
            self.tv_durum = "Kapalı"
            print("Televizyon kapatıldı.")

    def ses_ayarla(self):
        yeni_ses = int(input("Yeni ses seviyesini giriniz (0-100): "))
        if 0 <= yeni_ses <= 100:
            self.ses = yeni_ses
            print(f"Ses seviyesi ayarlandı: {self.ses}")
        else:
            print("Geçersiz ses seviyesi!")

    def kanal_ekle(self, kanal):
        self.kanal_listesi.append(kanal)
        print(f"{kanal} kanalı eklendi.")

    def kanal_sayisi(self):
        print(f"Toplam kanal sayısı: {len(self.kanal_listesi)}")

    def rastgele_kanal_gec(self):
        self.mevcut_kanal = random.choice(self.kanal_listesi)
        print(f"Yeni kanal: {self.mevcut_kanal}")

    def tv_bilgileri(self):
        print(f"TV Durumu: {self.tv_durum}\nSes Seviyesi: {self.ses}\nMevcut Kanal: {self.mevcut_kanal}\nKanallar: {self.kanal_listesi}")

def ana_menu():
    kumanda = Kumanda()

    while True:
        print("\n1. Tv Aç\n2. Tv Kapat\n3. Ses Ayarları\n4. Kanal Ekle\n5. Kanal Sayısını Öğrenme\n6. Rastgele Kanala Geçme\n7. Televizyon Bilgileri\nQ. Çıkış")
        secim = input("Yapmak istediğiniz işlemi seçiniz: ").lower()

        if secim == "1":
            kumanda.tv_ac()
        elif secim == "2":
            kumanda.tv_kapat()
        elif secim == "3":
            kumanda.ses_ayarla()
        elif secim == "4":
            kanal = input("Eklemek istediğiniz kanal adını girin: ")
            kumanda.kanal_ekle(kanal)
        elif secim == "5":
            kumanda.kanal_sayisi()
        elif secim == "6":
            kumanda.rastgele_kanal_gec()
        elif secim == "7":
            kumanda.tv_bilgileri()
        elif secim == "q":
            print("Çıkış yapılıyor...")
            time.sleep(1)
            break
        else:
            print("Geçersiz işlem! Lütfen tekrar deneyin.")

ana_menu()
