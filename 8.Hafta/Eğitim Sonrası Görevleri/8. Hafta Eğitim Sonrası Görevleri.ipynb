# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
def vki_sinifi(vki):
    if vki < 18.5:
        return "Zayıf"
    elif 18.5 <= vki <= 24.9:
        return "Normal kilolu"
    elif 25 <= vki <= 29.9:
        return "Fazla kilolu"
    elif 30 <= vki <= 39.9:
        return "Obez"
    else:
        return "İleri derecede obez (morbid obez)"

def veri_girisi():
    giris_sayisi = int(input("Kaç kişi için veri girişi yapılacak? "))
    
    with open("vki_kayitlari.txt", "w", encoding="utf-8") as dosya:
        for i in range(giris_sayisi):
            print(f"\n{i+1}. Kişi bilgileri:")
            ad_soyad = input("Ad Soyad: ")
            yas = input("Yaş: ")
            boy = float(input("Boy (metre cinsinden, örn. 1.75): "))
            kilo = float(input("Kilo (kg): "))
            
            vki = kilo / (boy ** 2)
            sinif = vki_sinifi(vki)
            
           
            dosya.write(f"{ad_soyad}, Yaş: {yas}, Boy: {boy}, Kilo: {kilo}, VKI: {vki:.2f}, Sınıf: {sinif}\n")
        
        print("\nTüm veriler başarıyla kaydedildi!")
veri_girisi()
# Out:
# 1. Kişi bilgileri:
#
# 2. Kişi bilgileri:
#
# Tüm veriler başarıyla kaydedildi!

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
import datetime

menu = {
    "Çilek": 10,
    "Muz": 8,
    "Ispanak": 5,
    "Protein Tozu": 15,
    "Badem Sütü": 7,
    "Yulaf": 4
}

def menuyu_goruntule():
    print("\n--- MENÜ ---")
    for urun, fiyat in menu.items():
        print(f"{urun}: {fiyat} TL")

def satin_al():
    sepet = []
    toplam = 0

    print("\nSmoothie için ürünleri seçin. Bitirmek için 'q' yazın.")
    while True:
        urun = input("Ürün adı: ").title()
        if urun == 'Q':
            break
        elif urun in menu:
            sepet.append(urun)
            toplam += menu[urun]
            print(f"{urun} eklendi. Ara toplam: {toplam} TL")
        else:
            print("Geçersiz ürün! Lütfen menüden bir ürün seçin.")

    if not sepet:
        print("Hiçbir ürün seçilmedi.")
        return

    tarih = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    with open("siparis_kayitlari.txt", "a", encoding="utf-8") as f:
        f.write(f"Tarih: {tarih}, Ürünler: {', '.join(sepet)}, Toplam: {toplam} TL\n")

    print(f"\nSipariş alındı! Toplam tutar: {toplam} TL")

def ana_menu():
    while True:
        print("\nYetBar Otomatına Hoş Geldiniz!")
        print("1. Menüyü Görüntüle")
        print("2. Satın Alma")
        print("3. Çıkış")

        secim = input("Seçiminiz: ")

        if secim == "1":
            menuyu_goruntule()
        elif secim == "2":
            satin_al()
        elif secim == "3":
            print("Çıkış yapılıyor. İyi günler!")
            break
        else:
            print("Geçersiz seçim. Lütfen tekrar deneyin.")

ana_menu()
# Out:
# YetBar Otomatına Hoş Geldiniz!
# 1. Menüyü Görüntüle
# 2. Satın Alma
# 3. Çıkış
# Geçersiz seçim. Lütfen tekrar deneyin.
#
# YetBar Otomatına Hoş Geldiniz!
# 1. Menüyü Görüntüle
# 2. Satın Alma
# 3. Çıkış
# Geçersiz seçim. Lütfen tekrar deneyin.
#
# YetBar Otomatına Hoş Geldiniz!
# 1. Menüyü Görüntüle
# 2. Satın Alma
# 3. Çıkış
# Geçersiz seçim. Lütfen tekrar deneyin.
#
# YetBar Otomatına Hoş Geldiniz!
# 1. Menüyü Görüntüle
# 2. Satın Alma
# 3. Çıkış
# Geçersiz seçim. Lütfen tekrar deneyin.
#
# YetBar Otomatına Hoş Geldiniz!
# 1. Menüyü Görüntüle
# 2. Satın Alma
# 3. Çıkış
# Geçersiz seçim. Lütfen tekrar deneyin.
#
# YetBar Otomatına Hoş Geldiniz!
# 1. Menüyü Görüntüle
# 2. Satın Alma
# 3. Çıkış
